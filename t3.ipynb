# %% [markdown]
# # Работа с инструментами разметки
#
# Мы видим, что модель некоторые точки неверно детектирует на скачанных нами лицах и мы хотим отправить эти данные на разметку человеком. Для этого мы хотим в инструмент для разметки данных загрузить изображения и предсказания модели для последующего исправления людьми. Соответственно в этом задании нужно:
#
# 1. завести если нет аккаунт на сервисе supervisely
#
# 2. почитать документацию и разобраться с SDK/Python-API для supervisely
#
# 3. написать код для загрузки данных в supervisely (в этом же jupyter-notebook)
#
# 4. загрузить 5-10 изображений и предсказаний модели в supervisely и вставить скриншот с работающего сервиса
#
# 5. замерьте скорость разметки и оцените время разметки с нуля и время доразметки результатов работы модели

# %%
import supervisely as sly


api_token = "ugc4tXGhgXx8ZYLL2Fz6GHWM3T5xJQmdOgqeK4lQJGp4zgbmaF0NXvEGG0QnteYcNd6xB0aZa42dPD1xnSeBZbGhDYNjS7Kk7ZDk2E0CUskryMkYxHMWfpZyXXnpgbZ6"
address = ''???
api = sly.Api(address, api_token)

# Создание проекта и датасета
workspace_name = 'your_workspace'
project_name = 'your_project'
project = api.project.create(workspace_name, project_name)
dataset_name = 'your_dataset'
dataset = api.dataset.create(project.id, dataset_name)

# Загрузка разметки из файла (например, COCO)
annotation_path = '/path/to/annotations.json'
sly.io.import_annotations_from_json(dataset.id, annotation_path)

# Закрытие проекта
api.project.close(project.id)
# Out:
# {"message": "Temporary connection error, please wait ...:  Retrying (1/10).", "method": "projects.add", "url": "https://your.supervisely.server/public/api/v3/projects.add", "details": "HTTPSConnectionPool(host='your.supervisely.server', port=443): Max retries exceeded with url: /public/api/v3/projects.add (Caused by NameResolutionError(\"<urllib3.connection.HTTPSConnection object at 0x292684460>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)\"))", "timestamp": "2024-06-24T17:33:37.199Z", "level": "warn"}
# {"message": "Temporary connection error, please wait ...:  Retrying (2/10).", "method": "projects.add", "url": "https://your.supervisely.server/public/api/v3/projects.add", "details": "HTTPSConnectionPool(host='your.supervisely.server', port=443): Max retries exceeded with url: /public/api/v3/projects.add (Caused by NameResolutionError(\"<urllib3.connection.HTTPSConnection object at 0x2938e14b0>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)\"))", "timestamp": "2024-06-24T17:33:38.212Z", "level": "warn"}
# {"message": "Temporary connection error, please wait ...:  Retrying (3/10).", "method": "projects.add", "url": "https://your.supervisely.server/public/api/v3/projects.add", "details": "HTTPSConnectionPool(host='your.supervisely.server', port=443): Max retries exceeded with url: /public/api/v3/projects.add (Caused by NameResolutionError(\"<urllib3.connection.HTTPSConnection object at 0x2938e1c90>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)\"))", "timestamp": "2024-06-24T17:33:40.226Z", "level": "warn"}
# {"message": "Temporary connection error, please wait ...:  Retrying (4/10).", "method": "projects.add", "url": "https://your.supervisely.server/public/api/v3/projects.add", "details": "HTTPSConnectionPool(host='your.supervisely.server', port=443): Max retries exceeded with url: /public/api/v3/projects.add (Caused by NameResolutionError(\"<urllib3.connection.HTTPSConnection object at 0x2926856f0>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)\"))", "timestamp": "2024-06-24T17:33:44.241Z", "level": "warn"}
# {"message": "Temporary connection error, please wait ...:  Retrying (5/10).", "method": "projects.add", "url": "https://your.supervisely.server/public/api/v3/projects.add", "details": "HTTPSConnectionPool(host='your.supervisely.server', port=443): Max retries exceeded with url: /public/api/v3/projects.add (Caused by NameResolutionError(\"<urllib3.connection.HTTPSConnection object at 0x2938e1690>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)\"))", "timestamp": "2024-06-24T17:33:52.250Z", "level": "warn"}
# {"message": "Temporary connection error, please wait ...:  Retrying (6/10).", "method": "projects.add", "url": "https://your.supervisely.server/public/api/v3/projects.add", "details": "HTTPSConnectionPool(host='your.supervisely.server', port=443): Max retries exceeded with url: /public/api/v3/projects.add (Caused by NameResolutionError(\"<urllib3.connection.HTTPSConnection object at 0x2938e0eb0>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)\"))", "timestamp": "2024-06-24T17:34:08.283Z", "level": "warn"}
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/connection.py:616, in HTTPSConnection.connect(self)
#     615 sock: socket.socket | ssl.SSLSocket
# --> 616 self.sock = sock = self._new_conn()
#     617 server_hostname: str = self.host
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x2938e0eb0>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='your.supervisely.server', port=443): Max retries exceeded with url: /public/api/v3/projects.add (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x2938e0eb0>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/supervisely/api/api.py:644, in Api.post(self, method, data, retries, stream, raise_error)
#     643         json_body = {**data, **self.additional_fields}
# --> 644     response = requests.post(
#     645         url, json=json_body, headers=self.headers, stream=stream
#     646     )
#     648 if response.status_code != requests.codes.ok:  # pylint: disable=no-member
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     104 r"""Sends a POST request.
#     105
#     106 :param url: URL for the new :class:`Request` object.
#    (...)
#     112 :rtype: requests.Response
#     113 """
# --> 115 return request("post", url, data=data, json=json, **kwargs)
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='your.supervisely.server', port=443): Max retries exceeded with url: /public/api/v3/projects.add (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x2938e0eb0>: Failed to resolve 'your.supervisely.server' ([Errno 8] nodename nor servname provided, or not known)"))
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 11
#       9 workspace_name = 'your_workspace'
#      10 project_name = 'your_project'
# ---> 11 project = api.project.create(workspace_name, project_name)
#      12 dataset_name = 'your_dataset'
#      13 dataset = api.dataset.create(project.id, dataset_name)
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/supervisely/api/project_api.py:610, in ProjectApi.create(self, workspace_id, name, type, description, change_name_if_conflict)
#     557 """
#     558 Create Project with given name in the given Workspace ID.
#     559
#    (...)
#     603
#     604 """
#     605 effective_name = self._get_effective_new_name(
#     606     parent_id=workspace_id,
#     607     name=name,
#     608     change_name_if_conflict=change_name_if_conflict,
#     609 )
# --> 610 response = self._api.post(
#     611     "projects.add",
#     612     {
#     613         ApiField.WORKSPACE_ID: workspace_id,
#     614         ApiField.NAME: effective_name,
#     615         ApiField.DESCRIPTION: description,
#     616         ApiField.TYPE: str(type),
#     617     },
#     618 )
#     619 return self._convert_json_info(response.json())
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/supervisely/api/api.py:656, in Api.post(self, method, data, retries, stream, raise_error)
#     654         raise exc
#     655     else:
# --> 656         process_requests_exception(
#     657             self.logger,
#     658             exc,
#     659             method,
#     660             url,
#     661             verbose=True,
#     662             swallow_exc=True,
#     663             sleep_sec=min(self.retry_sleep_sec * (2**retry_idx), 60),
#     664             response=response,
#     665             retry_info={"retry_idx": retry_idx + 1, "retry_limit": retries},
#     666         )
#     667 except Exception as exc:
#     668     process_unhandled_request(self.logger, exc)
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/supervisely/io/network_exceptions.py:45, in process_requests_exception(external_logger, exc, api_method_name, url, verbose, swallow_exc, sleep_sec, response, retry_info)
#      42         pass
#      44 if is_connection_error or is_server_retryable_error:
# ---> 45     process_retryable_request(external_logger, exc, api_method_name, url,
#      46                               CONNECTION_ERROR,
#      47                               verbose=verbose, swallow_exc=swallow_exc, sleep_sec=sleep_sec, retry_info=retry_info)
#      48 elif is_need_ping_error:
#      49     process_retryable_request(external_logger, exc, api_method_name, url,
#      50                               AGENT_CONNECTION_ERROR,
#      51                               verbose=verbose, swallow_exc=swallow_exc, sleep_sec=sleep_sec, retry_info=retry_info)
#
# File ~/Desktop/OneCell/onecell_env/lib/python3.10/site-packages/supervisely/io/network_exceptions.py:68, in process_retryable_request(external_logger, exc, api_method_name, url, user_message, verbose, swallow_exc, sleep_sec, retry_info)
#      65     external_logger.warn(user_message, extra={'method': api_method_name, 'url': url, 'details': str(exc)})
#      67 if sleep_sec is not None:
# ---> 68     time.sleep(sleep_sec)
#      70 if not swallow_exc:
#      71     raise exc
#
# KeyboardInterrupt:
